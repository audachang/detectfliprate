# %%
# %matplotlib inline

# %% [markdown]
# ## Open two command prompts
# ## Execute [measure_flip_rates.py](measure_flip_rates.py) in the first window
# * Here the script is reading input from analog pin 0, and will be start measuring when receiving difference larger than 0.3 in consecutive samples.
# * The measurement will last for 4 seconds.

# %% [markdown]
# ```MSDOS
# python measure_flip_rate.py 0 0.3 4 # arguments Apin, threshold, duration
# ```

# %% [markdown]
# ## Execute [flip_screen.py](flip_screen.py) in the second command prompt window
# * In this example we flash the screen at 4Hz for 5 seconds in full screen mode.

# %% [markdown]
# ```MSDOS
#
# python flip_screen.py 4 5 True # arguments: Frequency(Hz), duration, fullscreen flag
#
# ```
# * The command prompts look like what is shown below

# %% [markdown]
# ![flip_measure](flip_measure.jpg)

# %% [markdown]
# ## Attach the sensor to the screen when instructed.
# * the program will prompt you to attach the sensor first and then hit enter to start the flashing.

# %% [markdown]
# ![screen](flip_screen.jpg)

# %% [markdown]
# ## Execute plot_fliprate.py to show the parameters
# * After both scripts complete, you will run the plot_fliprate.py script to demonstrate the readings.

# %%
run plot_fliprate.py

# %% [markdown]
# ### What the graphs above mean:
# * The top graph showed the changes of light level measured by the light sensor throughout the 4 seconds.
# * The bottom graph showed the distribution of durations between inidividual flips.
# * At 4Hz, duration between flips is expected to be .25 seconds. The actual measurement jittered around the ideal value.
